# %%
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as layers

from tensorflow_io.bigquery import BigQueryClient

import functools

# %%
client = BigQueryClient()

# %%
GCP_PROJECT_ID = 'dataorg-hackweek-2021'
DATASET_GCP_PROJECT_ID = GCP_PROJECT_ID # A copy of the data is saved in the user project
DATASET_ID = 'mlhackweek_search.action' # moz-fx-data-shared-prod.mlhackweek_search_live.action_v1

# %%
# %load_ext google.cloud.bigquery
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
# %%bigquery
# SELECT
#   *
# FROM `moz-fx-data-shared-prod.mlhackweek_search_live.action_v1`
# where DATE(submission_timestamp) >= DATE('2021-01-19') and metrics.string.search_meta_session_id is not NULL LIMIT 1000
# Out:
# Query complete after 0.01s: 100%|██████████| 3/3 [00:00<00:00, 1270.74query/s]
# Downloading: 100%|██████████| 229/229 [00:01<00:00, 179.64rows/s]
#     additional_properties                                        client_info  \
# 0                      {}  {'android_sdk_version': None, 'app_build': 'Un...
# 1                      {}  {'android_sdk_version': None, 'app_build': 'Un...
# 2                      {}  {'android_sdk_version': None, 'app_build': 'Un...
# 3                      {}  {'android_sdk_version': None, 'app_build': 'Un...
# 4                      {}  {'android_sdk_version': None, 'app_build': 'Un...
# ..                    ...                                                ...
# 224                    {}  {'android_sdk_version': None, 'app_build': 'Un...
# 225                    {}  {'android_sdk_version': None, 'app_build': 'Un...
# 226                    {}  {'android_sdk_version': None, 'app_build': 'Un...
# 227                    {}  {'android_sdk_version': None, 'app_build': 'Un...
# 228                    {}  {'android_sdk_version': None, 'app_build': 'Un...
#
#                               document_id events  \
# 0    0258225b-b14f-4862-aea8-3b8133ae3a5f     []
# 1    bfe18f35-96cd-44c3-9187-fa51c6589af2     []
# 2    697e7f9b-2e18-402b-b29b-5e682729ec31     []
# 3    eb476ea9-9a24-4a4c-a4ed-effb7e487098     []
# 4    91729d7d-03a1-4397-b2d0-d4145c828176     []
# ..                                    ...    ...
# 224  5fcc9fb0-25e4-4235-be01-8b83e5d4f302     []
# 225  9f8b4feb-fbe6-475f-9c7c-a9af09ba41f3     []
# 226  e4cc018e-fd68-46bf-be4a-bef4759a1f48     []
# 227  01011477-0796-4796-89c2-2eb64e068560     []
# 228  fe305661-1ac4-4c34-935c-71fe445b4a38     []
#
#                                               metadata  \
# 0    {'geo': {'city': 'Council Bluffs', 'country': ...
# 1    {'geo': {'city': 'Council Bluffs', 'country': ...
# 2    {'geo': {'city': 'Council Bluffs', 'country': ...
# 3    {'geo': {'city': 'Council Bluffs', 'country': ...
# 4    {'geo': {'city': 'Council Bluffs', 'country': ...
# ..                                                 ...
# 224  {'geo': {'city': 'Council Bluffs', 'country': ...
# 225  {'geo': {'city': 'Council Bluffs', 'country': ...
# 226  {'geo': {'city': 'Council Bluffs', 'country': ...
# 227  {'geo': {'city': 'Council Bluffs', 'country': ...
# 228  {'geo': {'city': 'Council Bluffs', 'country': ...
#
#                                                metrics normalized_app_name  \
# 0    {'datetime': {'search_url_select_timestamp': N...                None
# 1    {'datetime': {'search_url_select_timestamp': N...                None
# 2    {'datetime': {'search_url_select_timestamp': N...                None
# 3    {'datetime': {'search_url_select_timestamp': N...                None
# 4    {'datetime': {'search_url_select_timestamp': N...                None
# ..                                                 ...                 ...
# 224  {'datetime': {'search_url_select_timestamp': N...                None
# 225  {'datetime': {'search_url_select_timestamp': N...                None
# 226  {'datetime': {'search_url_select_timestamp': N...                None
# 227  {'datetime': {'search_url_select_timestamp': N...                None
# 228  {'datetime': {'search_url_select_timestamp': N...                None
#
#     normalized_channel normalized_country_code normalized_os  \
# 0                 None                      US         Linux
# 1                 None                      US         Linux
# 2                 None                      US         Linux
# 3                 None                      US         Linux
# 4                 None                      US         Linux
# ..                 ...                     ...           ...
# 224               None                      US         Linux
# 225               None                      US         Linux
# 226               None                      US         Linux
# 227               None                      US         Linux
# 228               None                      US         Linux
#
#     normalized_os_version                                          ping_info  \
# 0                 5.4.120  {'end_time': '2021-09-27T15:39+00:00', 'experi...
# 1                 5.4.120  {'end_time': '2021-09-27T15:38+00:00', 'experi...
# 2                 5.4.120  {'end_time': '2021-09-27T15:39+00:00', 'experi...
# 3                 5.4.120  {'end_time': '2021-09-27T15:08+00:00', 'experi...
# 4                 5.4.120  {'end_time': '2021-09-27T13:43+00:00', 'experi...
# ..                    ...                                                ...
# 224               5.4.120  {'end_time': '2021-09-28T16:05+00:00', 'experi...
# 225               5.4.120  {'end_time': '2021-09-28T16:29+00:00', 'experi...
# 226               5.4.120  {'end_time': '2021-09-28T16:28+00:00', 'experi...
# 227               5.4.120  {'end_time': '2021-09-28T16:29+00:00', 'experi...
# 228               5.4.120  {'end_time': '2021-09-28T16:30+00:00', 'experi...
#
#      sample_id             submission_timestamp
# 0          NaN 2021-09-27 15:39:26.799013+00:00
# 1          NaN 2021-09-27 15:38:54.086750+00:00
# 2          NaN 2021-09-27 15:39:47.730126+00:00
# 3          NaN 2021-09-27 15:08:18.411322+00:00
# 4          NaN 2021-09-27 13:43:19.987561+00:00
# ..         ...                              ...
# 224        NaN 2021-09-28 16:05:57.225523+00:00
# 225        NaN 2021-09-28 16:29:29.460265+00:00
# 226        NaN 2021-09-28 16:28:46.922354+00:00
# 227        NaN 2021-09-28 16:29:37.334024+00:00
# 228        NaN 2021-09-28 16:30:13.600990+00:00
#
# [229 rows x 14 columns]
